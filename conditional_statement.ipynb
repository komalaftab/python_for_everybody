# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
is_hot = True
is_cold =False
if is_hot:
    print("It's a hot day.")
    print("Drink plenty of water.")
elif is_cold:
    print("It's a cold day.")
    print("Wear warm clothes.")
else:
    print("It's a lovely day.")
# Out:
# It's a hot day.
# Drink plenty of water.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
price =1000000
has_good_credit = False
if has_good_credit:
    down_payment = price * 0.1
else:
    down_payment = price * 0.2
print(f"Down payment:{down_payment}")
# Out:
# Down payment:200000.0

# %% [markdown]
# # Problem::
# Take a variable x and print "even".if it 's divisible by 2.otherwise it's odd.

# %%
x =int(input("Enter a number?"))
if x%2==0:
    print("Number is even.")
else:
    print("Number is odd.")
# Out:
# Enter a number?6
# Number is even.

# %% [markdown]
# Take a variable y and print "Grade A" if y is greater than 90,"Grade B".if Y is greater than 60 but les than or equalto 90 and "Grade F".

# %%
y =int(input("enter a number?"))
if y > 90:
    print("Grade A")
elif y> 60 & y<=90:
    print("Grade B")
else:
    print("Grade F")
# Out:
# enter a number?90
# Grade B

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
temp =int(input("Enter temperature:"))
if temp >= 30:
    print("it's a hot day.")
elif temp < 10:
    print("it's a cold day.")
else:
    print("it's neither hot nor cold.")
# Out:
# Enter temperature:45
# it's a hot day.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
name = input("enter yur name?")
x = len(name)
if x < 3 :
    print("Name must be at least 3 characters.")
elif x>50:
    print("Name can be a maximum of 50 characters.")
else:
    print("name looks good!")
# Out:
# enter yur name?ali
# name looks good!
