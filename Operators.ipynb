# %% [markdown]
# ### Operators::

# %% [markdown]
# ### What are operators?

# %% [markdown]
# #### Symbolic representions of mathematical task.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Math Functions::

# %%
# How to round float number?
x = 3.5
print(round(x))
# Out:
# 4

# %%
print(abs(-8.0))
# Out:
# 8.0

# %%
import math

# %%
math.ceil(12.3)
# Out:
# 13

# %% [markdown]
# # https://docs.python.org/3/tutorial/modules.html
#
# math module
